# %%
# !pip install deep-sort-realtime
# !pip install opencv-python-headless
# !pip install ultralytics
# !pip install torchreid

# !git clone https://github.com/KaiyangZhou/deep-person-reid.git
# %cd deep-person-reid
# !pip install -e .

# !pip install torchvision
# Out:
# Collecting deep-sort-realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from deep-sort-realtime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from deep-sort-realtime) (1.15.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from deep-sort-realtime) (4.11.0.86)
# Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 25.0 MB/s eta 0:00:00
# Installing collected packages: deep-sort-realtime
# Successfully installed deep-sort-realtime-1.3.2

# %% [markdown]
# Best.py model inference

# %%
from ultralytics import YOLO
import cv2
import os
from IPython.display import Image, display
from torchvision.models import resnet50
from scipy.optimize import linear_sum_assignment
import torch
import numpy as np
from deep_sort_realtime.deepsort_tracker import DeepSort
from sklearn.metrics.pairwise import cosine_similarity
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms

# %%
# Make sure to change the path to where the best.pt model is stored
yolo = YOLO("best.pt")

# Load a frame from a video to perform the inference
video_path = "Videos/broadcast.mp4"
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
cap.release()

if not ret:
    raise ValueError("Could not read a frame from the video.")

# Run inference
results = yolo(frame)

# Annotate image with bounding boxes
annotated_frame = results[0].plot()

# Save the annotated image
#cv2.imwrite("/content/annotated_output.jpg", annotated_frame)

# OPTIONAL: Show it inline (if using Jupyter or Colab)

display(Image(filename="/content/annotated_output.jpg"))

# %%
# --- Config ---
VIDEO_PATH = "Videos/broadcast.mp4"
OUTPUT_PATH = "Videos/broadcast_yolo_only.mp4"


class_names = yolo.names  # e.g., {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}

# --- Open Video ---
cap = cv2.VideoCapture(VIDEO_PATH)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(OUTPUT_PATH, fourcc, fps, (width, height))

# --- Frame-by-frame detection ---
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO inference
    results = yolo(frame)[0]

    # Draw detections
    for box in results.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = box.conf[0].item()
        cls = int(box.cls[0])
        label = f"{class_names[cls]} {conf:.2f}"
        color = (0, 255, 0) if cls == 2 else (255, 0, 0)  # green for player, blue for others

        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    out.write(frame)

# --- Cleanup ---
cap.release()
out.release()
print("Done! YOLO-only tracked video saved to:", OUTPUT_PATH)
# Out:
# 0: 384x640 3 players, 2689.2ms
# Speed: 3.4ms preprocess, 2689.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 3118.8ms
# Speed: 4.0ms preprocess, 3118.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 3634.1ms
# Speed: 5.6ms preprocess, 3634.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 2679.6ms
# Speed: 4.9ms preprocess, 2679.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 2518.2ms
# Speed: 4.6ms preprocess, 2518.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2734.2ms
# Speed: 3.5ms preprocess, 2734.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 3973.3ms
# Speed: 3.6ms preprocess, 3973.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 14 players, 1 referee, 2816.2ms
# Speed: 9.3ms preprocess, 2816.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 2672.4ms
# Speed: 3.9ms preprocess, 2672.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 2551.7ms
# Speed: 4.2ms preprocess, 2551.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2688.2ms
# Speed: 5.1ms preprocess, 2688.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 4236.2ms
# Speed: 4.3ms preprocess, 4236.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2701.7ms
# Speed: 4.2ms preprocess, 2701.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2577.9ms
# Speed: 4.3ms preprocess, 2577.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3 referees, 2605.5ms
# Speed: 5.7ms preprocess, 2605.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 3410.0ms
# Speed: 3.4ms preprocess, 3410.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 3555.9ms
# Speed: 5.7ms preprocess, 3555.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 2702.0ms
# Speed: 3.2ms preprocess, 2702.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2 referees, 2527.0ms
# Speed: 3.7ms preprocess, 2527.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2548.3ms
# Speed: 3.3ms preprocess, 2548.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 4327.3ms
# Speed: 4.0ms preprocess, 4327.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2639.5ms
# Speed: 4.4ms preprocess, 2639.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2628.4ms
# Speed: 5.5ms preprocess, 2628.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2542.8ms
# Speed: 3.8ms preprocess, 2542.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2876.3ms
# Speed: 4.3ms preprocess, 2876.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 4022.1ms
# Speed: 5.1ms preprocess, 4022.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 2537.9ms
# Speed: 4.0ms preprocess, 2537.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 2685.7ms
# Speed: 3.7ms preprocess, 2685.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 2695.0ms
# Speed: 4.1ms preprocess, 2695.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 3623.0ms
# Speed: 4.0ms preprocess, 3623.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 3253.6ms
# Speed: 4.0ms preprocess, 3253.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 2598.5ms
# Speed: 5.5ms preprocess, 2598.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 2542.1ms
# Speed: 4.1ms preprocess, 2542.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2689.0ms
# Speed: 4.5ms preprocess, 2689.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 4210.4ms
# Speed: 3.8ms preprocess, 4210.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2666.8ms
# Speed: 4.3ms preprocess, 2666.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2678.0ms
# Speed: 4.0ms preprocess, 2678.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2708.6ms
# Speed: 4.0ms preprocess, 2708.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 3078.8ms
# Speed: 4.4ms preprocess, 3078.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 3889.4ms
# Speed: 4.0ms preprocess, 3889.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2549.2ms
# Speed: 4.3ms preprocess, 2549.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2690.9ms
# Speed: 5.5ms preprocess, 2690.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 2678.7ms
# Speed: 4.3ms preprocess, 2678.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 3714.6ms
# Speed: 4.3ms preprocess, 3714.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 3123.3ms
# Speed: 3.9ms preprocess, 3123.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2684.2ms
# Speed: 3.4ms preprocess, 2684.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 2524.2ms
# Speed: 7.3ms preprocess, 2524.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1 referee, 2687.1ms
# Speed: 4.0ms preprocess, 2687.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 4290.9ms
# Speed: 4.3ms preprocess, 4290.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2515.0ms
# Speed: 3.8ms preprocess, 2515.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2688.8ms
# Speed: 3.3ms preprocess, 2688.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 12 players, 2708.4ms
# Speed: 6.3ms preprocess, 2708.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2889.8ms
# Speed: 4.2ms preprocess, 2889.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 3832.4ms
# Speed: 5.1ms preprocess, 3832.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2689.8ms
# Speed: 4.2ms preprocess, 2689.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2537.5ms
# Speed: 4.9ms preprocess, 2537.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 2650.6ms
# Speed: 4.0ms preprocess, 2650.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 3651.1ms
# Speed: 3.8ms preprocess, 3651.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 3125.5ms
# Speed: 4.6ms preprocess, 3125.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 2682.9ms
# Speed: 3.6ms preprocess, 2682.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 2700.9ms
# Speed: 3.9ms preprocess, 2700.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3 referees, 2548.5ms
# Speed: 4.2ms preprocess, 2548.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 4225.7ms
# Speed: 3.4ms preprocess, 4225.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2690.5ms
# Speed: 4.0ms preprocess, 2690.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2573.6ms
# Speed: 4.0ms preprocess, 2573.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 2516.1ms
# Speed: 4.7ms preprocess, 2516.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2928.5ms
# Speed: 3.8ms preprocess, 2928.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 3930.9ms
# Speed: 3.8ms preprocess, 3930.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 2508.0ms
# Speed: 4.1ms preprocess, 2508.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 2683.5ms
# Speed: 3.7ms preprocess, 2683.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 2669.6ms
# Speed: 4.7ms preprocess, 2669.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 3635.2ms
# Speed: 3.8ms preprocess, 3635.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 3383.6ms
# Speed: 4.0ms preprocess, 3383.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2526.2ms
# Speed: 4.9ms preprocess, 2526.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3 referees, 2693.8ms
# Speed: 3.8ms preprocess, 2693.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2699.3ms
# Speed: 3.5ms preprocess, 2699.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 4298.9ms
# Speed: 4.0ms preprocess, 4298.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2545.1ms
# Speed: 3.9ms preprocess, 2545.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 2524.9ms
# Speed: 4.1ms preprocess, 2524.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2679.6ms
# Speed: 3.8ms preprocess, 2679.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 3033.6ms
# Speed: 4.2ms preprocess, 3033.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 3931.5ms
# Speed: 8.1ms preprocess, 3931.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1 referee, 2545.3ms
# Speed: 3.3ms preprocess, 2545.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2728.6ms
# Speed: 3.1ms preprocess, 2728.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 1 referee, 2755.5ms
# Speed: 5.1ms preprocess, 2755.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 3767.6ms
# Speed: 5.0ms preprocess, 3767.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2963.9ms
# Speed: 11.1ms preprocess, 2963.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2677.7ms
# Speed: 5.2ms preprocess, 2677.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2675.4ms
# Speed: 4.0ms preprocess, 2675.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2546.3ms
# Speed: 3.2ms preprocess, 2546.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 4252.7ms
# Speed: 4.1ms preprocess, 4252.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2672.4ms
# Speed: 4.3ms preprocess, 2672.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2534.6ms
# Speed: 3.7ms preprocess, 2534.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2650.7ms
# Speed: 4.2ms preprocess, 2650.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3360.7ms
# Speed: 4.4ms preprocess, 3360.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3419.0ms
# Speed: 4.8ms preprocess, 3419.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2527.1ms
# Speed: 5.0ms preprocess, 2527.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2651.3ms
# Speed: 5.0ms preprocess, 2651.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 12 players, 1 referee, 2663.3ms
# Speed: 3.8ms preprocess, 2663.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 3750.7ms
# Speed: 4.0ms preprocess, 3750.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3045.7ms
# Speed: 4.6ms preprocess, 3045.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2693.3ms
# Speed: 4.2ms preprocess, 2693.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2516.8ms
# Speed: 4.6ms preprocess, 2516.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2666.2ms
# Speed: 5.9ms preprocess, 2666.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 4302.6ms
# Speed: 4.0ms preprocess, 4302.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2653.1ms
# Speed: 5.0ms preprocess, 2653.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2520.4ms
# Speed: 4.5ms preprocess, 2520.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2656.4ms
# Speed: 4.3ms preprocess, 2656.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2886.1ms
# Speed: 4.3ms preprocess, 2886.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 3836.6ms
# Speed: 4.9ms preprocess, 3836.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 2 referees, 2677.2ms
# Speed: 4.7ms preprocess, 2677.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2537.8ms
# Speed: 4.8ms preprocess, 2537.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2627.7ms
# Speed: 4.3ms preprocess, 2627.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2 referees, 3657.0ms
# Speed: 4.4ms preprocess, 3657.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1 referee, 3329.9ms
# Speed: 4.8ms preprocess, 3329.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2483.4ms
# Speed: 17.0ms preprocess, 2483.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2570.3ms
# Speed: 5.0ms preprocess, 2570.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2652.1ms
# Speed: 4.0ms preprocess, 2652.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 4215.8ms
# Speed: 4.3ms preprocess, 4215.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2710.5ms
# Speed: 6.6ms preprocess, 2710.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2511.7ms
# Speed: 4.2ms preprocess, 2511.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2686.7ms
# Speed: 4.0ms preprocess, 2686.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2795.6ms
# Speed: 4.2ms preprocess, 2795.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 3983.7ms
# Speed: 4.2ms preprocess, 3983.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2557.5ms
# Speed: 4.3ms preprocess, 2557.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 2667.4ms
# Speed: 5.0ms preprocess, 2667.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2494.2ms
# Speed: 5.7ms preprocess, 2494.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 3455.7ms
# Speed: 4.2ms preprocess, 3455.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 3342.1ms
# Speed: 6.9ms preprocess, 3342.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2672.1ms
# Speed: 4.1ms preprocess, 2672.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2683.9ms
# Speed: 4.5ms preprocess, 2683.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2674.0ms
# Speed: 4.5ms preprocess, 2674.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Done! YOLO-only tracked video saved to: /content/drive/MyDrive/Stealth_Mode/Assignment Materials/broadcast_yolo_only.mp4

# %%
print(yolo.names)
# Out:
# {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}

# %%
# --- Cross-Camera Player Re-Identification Pipeline using Visual, Spatial, and Temporal Features ---

VIDEO_DIR = "Videos"
OUTPUT_DIR ="Results"

# Setting the confidence and similarity threshold for identifying the class and same player
CONF_THRESHOLD = 0.7
SIMILARITY_THRESHOLD = 0.90

# ------------------------ SETUP --------------------------

tracker = DeepSort(max_age=30, n_init=2)

resnet = resnet50(weights=models.ResNet50_Weights.DEFAULT)
resnet = torch.nn.Sequential(*list(resnet.children())[:-1])
resnet.eval()

preprocess = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet = resnet.to(device)

# ------------------------ FUNCTIONS --------------------------
def extract_embedding(crop):
    if crop is None or crop.shape[0] < 10 or crop.shape[1] < 10:
        return None
    try:
        img_tensor = preprocess(crop).unsqueeze(0).to(device)
        with torch.no_grad():
            feat = resnet(img_tensor).squeeze()
            if feat.dim() > 1:
                feat = feat.flatten()
            emb = F.normalize(feat, dim=0).cpu().numpy()
        return emb
    except:
        return None

def extract_track_features(video_path):
    cap = cv2.VideoCapture(video_path)
    track_data = {}
    frame_id = 0
    frame_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = yolo(frame, verbose=False)[0]
        detections = []
        for box in results.boxes:
            cls = int(box.cls[0])
            conf = float(box.conf[0])
            if cls == 2 and conf > CONF_THRESHOLD:
                x1, y1, x2, y2 = box.xyxy[0]
                detections.append(([float(x1), float(y1), float(x2 - x1), float(y2 - y1)], conf, "player"))

        tracks = tracker.update_tracks(detections, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue
            tid = track.track_id
            l, t, r, b = map(int, track.to_ltrb())
            cx = (l + r) / 2 / frame_w
            cy = (t + b) / 2 / frame_h
            crop = frame[t:b, l:r]
            feature = extract_embedding(crop)
            if feature is None:
                continue
            if tid not in track_data:
                track_data[tid] = {"features": [], "positions": []}
            track_data[tid]["features"].append(feature)
            track_data[tid]["positions"].append([cx, cy])

        frame_id += 1

    cap.release()

    # Aggregate features
    final_tracks = {}
    for tid, data in track_data.items():
        feats = np.array(data["features"])
        pos = np.array(data["positions"])

        # Visual: average embedding
        avg_feat = feats.mean(axis=0)
        avg_feat = avg_feat / np.linalg.norm(avg_feat)

        # Spatial: average position
        avg_pos = pos.mean(axis=0)

        # Temporal: motion sequence flattened (padded to length 10 if needed)
        motion = pos[1:] - pos[:-1]
        max_len = 10
        motion_flat = np.zeros(max_len * 2)
        valid_motion = motion[-max_len:]
        motion_flat[:valid_motion.size] = valid_motion.flatten()

        final_tracks[tid] = (avg_feat, avg_pos, motion_flat)

    return final_tracks




def match_tracks_hungarian(source_tracks, target_tracks):
    source_ids = list(source_tracks.keys())
    target_ids = list(target_tracks.keys())

    cost_matrix = np.zeros((len(target_ids), len(source_ids)))

    for i, tid in enumerate(target_ids):
        t_feat, t_pos, t_mov = target_tracks[tid]
        for j, sid in enumerate(source_ids):
            s_feat, s_pos, s_mov = source_tracks[sid]

            emb_score = cosine_similarity([t_feat], [s_feat])[0][0]
            pos_score = 1 - np.linalg.norm(t_pos - s_pos)
            mov_score = 1 - np.linalg.norm(t_mov - s_mov)

            # Cost = 1 - total score
            total_score = 0.6 * emb_score + 0.25 * pos_score + 0.15 * mov_score
            cost_matrix[i, j] = 1 - total_score

    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    mapping = {}
    for i, j in zip(row_ind, col_ind):
        score = 1 - cost_matrix[i, j]
        tid = int(target_ids[i])
        sid = int(source_ids[j])
        if score >= SIMILARITY_THRESHOLD:
            mapping[tid] = sid
        else:
            mapping[tid] = tid + 1000  # no confident match

    return mapping


def remap_and_save(video_path, id_map, output_path):
    cap = cv2.VideoCapture(video_path)
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'),
                          int(cap.get(cv2.CAP_PROP_FPS)),
                          (int(cap.get(3)), int(cap.get(4))))
    tracker = DeepSort(max_age=30, n_init=2)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = yolo(frame, verbose=False)[0]
        detections = []
        for box in results.boxes:
            cls = int(box.cls[0])
            conf = float(box.conf[0])
            if cls == 2 and conf > CONF_THRESHOLD:
                x1, y1, x2, y2 = box.xyxy[0]
                detections.append(([float(x1), float(y1), float(x2 - x1), float(y2 - y1)], conf, "player"))

        tracks = tracker.update_tracks(detections, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue

            tid_int = int(track.track_id)
            mapped_id = id_map.get(tid_int, tid_int + 1000)

            l, t, r, b = map(int, track.to_ltrb())
            cv2.rectangle(frame, (l, t), (r, b), (0, 255, 0), 2)
            cv2.putText(frame, f"ID: {mapped_id}", (l, t - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

        out.write(frame)

    cap.release()
    out.release()

# ------------------------ MAIN --------------------------
if __name__ == "__main__":
    broadcast_path = os.path.join(VIDEO_DIR, "broadcast.mp4")
    tacticam_path = os.path.join(VIDEO_DIR, "tacticam.mp4")

    # Extracting visual + spatial + temporal features from broadcast
    b_tracks = extract_track_features(broadcast_path)

    #Extracting visual + spatial + temporal features from tacticam
    t_tracks = extract_track_features(tacticam_path)

    #Matching players across videos
    id_map = match_tracks_hungarian(b_tracks, t_tracks)


    #Saving the remapped video
    remap_and_save(tacticam_path, id_map, os.path.join(OUTPUT_DIR, "tacticam_remapped.mp4"))

    #saving the tracked video
    remap_and_save(broadcast_path, {k: k for k in b_tracks}, os.path.join(OUTPUT_DIR, "broadcast_tracked.mp4"))
